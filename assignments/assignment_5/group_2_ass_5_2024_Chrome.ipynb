# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
# Create a Service object with the executable path
chrome_path = r'C:\Users\javie\OneDrive\Escritorio\Python\chromedriver-win64\chromedriver.exe'
chrome_service = webdriver.chrome.service.Service(chrome_path)

# Use the Service object when creating the Chrome WebDriver
driver = webdriver.Chrome(service=chrome_service)
driver.maximize_window()

# %%
# List of URL endings for each subpage
url_endings = ['segunda-vuelta-de-la-elección-presidencial-2006-presidencial_candidatos-y-resultados_vJqK+o5B88E=qo',
               'elecciones-generales-2006-presidencial_candidatos-y-resultados_bgnkVFt+VRk=nF',
               'segunda-vuelta-de-la-elección-presidencial-2001-presidencial_candidatos-y-resultados_3F8G0syb5XE=8s',
               'elecciones-generales-2001-presidencial_candidatos-y-resultados_+kvFvkuAfuw=vk',
               'segunda-vuelta-de-la-elección-presidencial-2000-presidencial_candidatos-y-resultados_r+6hROwHBIQ=6O',
               'elecciones-generales-2000-presidencial_candidatos-y-resultados_yny1iTkPazM=yT']

# Create an empty list to store the DataFrames
dfs = []

# Loop through each URL ending
for url_ending in url_endings:
    # Go to the website
    driver.get(f"https://infogob.jne.gob.pe/Eleccion/FichaEleccion/{url_ending}")

    # Add a delay so the elements can be found
    time.sleep(50)

    # Get the HTML of the page and pass it to BeautifulSoup
    soup = BeautifulSoup(driver.page_source, 'html.parser')

    # Find the table and the input element
    table = soup.find('table', {'id': 'gridEleccionResultadosElectorales'})

    # Check if the table was found correctly
    if table:
        # Get the value of the input element
        input_element = soup.find('input', {'id': 'nombreEleccion'})
        year = input_element['value']

        # Find all rows in the table
        rows = table.find_all('tr')

        # Create a list to store the data
        data = []

        # Loop through each row
        for row in rows:
            # Find all columns in each row
            cols = row.find_all('td')

            # Get the text from each column
            cols = [col.text.strip() for col in cols]

            # Add the columns to the data array
            data.append(cols)

        # Create a list to store the extracted data
        extracted_data = []

        # Loop through each list in data
        for data_list in data:
            if len(data_list) >= 4:
                # Extract the first and fourth items and add them to extracted_data
                extracted_data.append([data_list[0], data_list[3]])

        # Convert the extracted data to a DataFrame
        temp_df = pd.DataFrame(extracted_data, columns=['Organización Política', 'Total de votos'])

        # Create a new DataFrame with the new column
        new_df = pd.DataFrame({'Elecciones': [year] * len(temp_df)})

        # Concatenate the new DataFrame with the original DataFrame
        temp_df = pd.concat([new_df, temp_df], axis=1)

        # Append the DataFrame to the list
        dfs.append(temp_df)
    else:
        print(f"No se encontró la tabla en la página: {url_ending}")

# Finally we close the browser
driver.quit()

# To export into excel sheet, we concatenate all DataFrames in the list into a single DataFrame
df = pd.concat(dfs)

# Specify the path where you want to store the Excel file
file_path = r'C:\Users\javie\OneDrive\Escritorio\Python\group_2_ass5_2024.xlsx'

# Use the 'to_excel' function to export the DataFrame
df.to_excel(file_path, index=False)

# %%
import pandas as pd
from openpyxl import load_workbook

# %%
# Specify the path where your Excel file is stored
file_path = r"C:\Users\javie\Downloads\group_2_ass_5_2024.xlsx"

# Load the existing Excel file
book = load_workbook(file_path)

# Create a pandas Excel writer using openpyxl as the engine
writer = pd.ExcelWriter(file_path, engine='openpyxl')

# Assign the loaded workbook to the writer
writer.book = book

# Write the DataFrame to the Excel file
df.to_excel(writer, index=False)

# Save the changes in the writer object
writer.save()

# Close the writer and free up system resources
writer.close()

# %%
##José Poémape
# !pip install selenium
# !pip install webdriver manager
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import time
# Out:
# Requirement already satisfied: selenium in c:\users\jpc04\anaconda3\lib\site-packages (4.16.0)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in c:\users\jpc04\anaconda3\lib\site-packages (from selenium) (1.26.16)
# Requirement already satisfied: trio~=0.17 in c:\users\jpc04\anaconda3\lib\site-packages (from selenium) (0.24.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\jpc04\anaconda3\lib\site-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\jpc04\anaconda3\lib\site-packages (from selenium) (2023.7.22)
# Requirement already satisfied: attrs>=20.1.0 in c:\users\jpc04\anaconda3\lib\site-packages (from trio~=0.17->selenium) (22.1.0)
# Requirement already satisfied: sortedcontainers in c:\users\jpc04\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\jpc04\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: outcome in c:\users\jpc04\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\jpc04\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\jpc04\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\jpc04\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\jpc04\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\jpc04\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\jpc04\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# ERROR: Could not find a version that satisfies the requirement webdriver (from versions: none)
# ERROR: No matching distribution found for webdriver

# %%
##José Poémape
# Create a Service object with the executable path
chrome_path = r'C:\Users\jpc04\OneDrive\Documentos\8vo\pythqla\chromedriver-win64\chromedriver.exe'
chrome_service = webdriver.chrome.service.Service(chrome_path)

# Use the Service object when creating the Chrome WebDriver
driver = webdriver.Chrome(service=chrome_service)
driver.maximize_window()

# %%
##José Poémape

# List of URL endings for each subpage
url_endings = ['elecciones-generales-1962-presidencial_candidatos-y-resultados_rWwQzpPNurI=wp',
               'elecciones-generales-1956-presidencial_candidatos-y-resultados_WIHkyMA8HI8=HM',
               'elecciones-generales-1950-presidencial_candidatos-y-resultados_L5MJsms6q5Y=Mm',
               'elecciones-generales-1945-presidencial_candidatos-y-resultados_sY5dLXlhrMU=5X',
               'elecciones-generales-1939-presidencial_candidatos-y-resultados_ozbDLopjV7s=bo',
               'elecciones-generales-1936-presidencial_candidatos-y-resultados_dHU0mWeyL0k=UW',
               'elecciones-generales-1931-presidencial_candidatos-y-resultados_PrO34XpiKLg=OX']

# Create an empty list to store the DataFrames
dfs = []

# Loop through each URL ending
for url_ending in url_endings:
    # Go to the website
    driver.get(f"https://infogob.jne.gob.pe/Eleccion/FichaEleccion/{url_ending}")

    # Add a delay so the elements can be found
    time.sleep(50)

    # Get the HTML of the page and pass it to BeautifulSoup
    soup = BeautifulSoup(driver.page_source, 'html.parser')

    # Find the table and the input element
    table = soup.find('table', {'id': 'gridEleccionResultadosElectorales'})

    # Check if the table was found correctly
    if table:
        # Get the value of the input element
        input_element = soup.find('input', {'id': 'nombreEleccion'})
        year = input_element['value']

        # Find all rows in the table
        rows = table.find_all('tr')

        # Create a list to store the data
        data = []

        # Loop through each row
        for row in rows:
            # Find all columns in each row
            cols = row.find_all('td')

            # Get the text from each column
            cols = [col.text.strip() for col in cols]

            # Add the columns to the data array
            data.append(cols)

        # Create a list to store the extracted data
        extracted_data = []

        # Loop through each list in data
        for data_list in data:
            if len(data_list) >= 4:
                # Extract the first and fourth items and add them to extracted_data
                extracted_data.append([data_list[0], data_list[1]])

        # Convert the extracted data to a DataFrame
        temp_df = pd.DataFrame(extracted_data, columns=['Organización Política', 'Total de votos'])

        # Create a new DataFrame with the new column
        new_df = pd.DataFrame({'Elecciones': [year] * len(temp_df)})

        # Concatenate the new DataFrame with the original DataFrame
        temp_df = pd.concat([new_df, temp_df], axis=1)

        # Append the DataFrame to the list
        dfs.append(temp_df)
    else:
        print(f"No se encontró la tabla en la página: {url_ending}")

# Finally we close the browser
driver.quit()

# To export into excel sheet, we concatenate all DataFrames in the list into a single DataFrame
df = pd.concat(dfs)

# Specify the path where you want to store the Excel file
file_path = r'C:\Users\jpc04\OneDrive\Documentos\GitHub\QLAB_Summer_Python\assignments\assignment_5\group_2_ass_5_2024Poemape.xlsx'

# Use the 'to_excel' function to export the DataFrame
df.to_excel(file_path, index=False)

# %%
##José Poémape

import pandas as pd
from openpyxl import load_workbook

# Specify the path where your Excel file is stored
file_path = r'C:\Users\jpc04\OneDrive\Documentos\GitHub\QLAB_Summer_Python\assignments\assignment_5\group_2_ass_5_2024Poemape.xlsx'

# Load the existing Excel file
book = load_workbook(file_path)

# Create a pandas Excel writer using openpyxl as the engine
writer = pd.ExcelWriter(file_path, engine='openpyxl')

# Assign the loaded workbook to the writer
writer.book = book

# Write the DataFrame to the Excel file
df.to_excel(writer, index=False)

# Save the changes in the writer object
writer.save()

# Close the writer and free up system resources
writer.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 16
#      13 writer = pd.ExcelWriter(file_path, engine='openpyxl')
#      15 # Assign the loaded workbook to the writer
# ---> 16 writer.book = book
#      18 # Write the DataFrame to the Excel file
#      19 df.to_excel(writer, index=False)
#
# AttributeError: property 'book' of 'OpenpyxlWriter' object has no setter
