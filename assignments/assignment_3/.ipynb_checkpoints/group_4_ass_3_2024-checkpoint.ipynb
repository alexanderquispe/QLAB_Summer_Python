# %% [markdown]
# # 1

# %%
import pandas as pd

# Especifica la ruta del archivo Excel
ruta_del_archivo_excel = '../../_data/bogota_firms.xlsx'

# Usa la función read_excel para cargar los datos en un DataFrame
data_frame = pd.read_excel(ruta_del_archivo_excel, sheet_name='Results')

# Ahora puedes trabajar con tu DataFrame
# Por ejemplo, puedes imprimir las primeras filas del DataFrame
data_frame.head(5)

# Limpiando base de datos
# Reemplaza los valores nulos (NaN) por 0 en todo el DataFrame
data_frame_sin_na = data_frame.replace( "n.a.", 0)
data_frame_sin_na.head(5)
data_frame_sin_na.describe(include="all").round(4)
# Out:
#         Unnamed: 0 Company name Latin alphabet Country ISO code  \
# count   10000.0000                       10000            10000
# unique         NaN                        9996                1
# top            NaN             CHAMPLAST S A S               CO
# freq           NaN                           2            10000
# mean     5000.5000                         NaN              NaN
# std      2886.8957                         NaN              NaN
# min         1.0000                         NaN              NaN
# 25%      2500.7500                         NaN              NaN
# 50%      5000.5000                         NaN              NaN
# 75%      7500.2500                         NaN              NaN
# max     10000.0000                         NaN              NaN
#
#        City\nLatin Alphabet  NACE Rev. 2, core code (4 digits)  \
# count                  9992                          9650.0000
# unique                  507                                NaN
# ...

# %% [markdown]
# # 2

# %% [markdown]
# # 3

# %% [markdown]
# # 4

# %% [markdown]
# # 5

# %% [markdown]
# # 6
