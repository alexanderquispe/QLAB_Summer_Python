# %% [markdown]
# ## Assignment 3 - Group 1
#
# 1. Inspect this dataset `./_data/bogota_firms.xlsx` and show some descriptive statistics of it.

# %%
## First of all, we import the libraries to be used in this work:
import numpy as np
import pandas as pd 
pd.set_option('display.float_format', '{:.2f}'.format) # With this all the numbers in the Dataframe will be shown with only 2 decimal places. This is to improve visualization.

# %%
## We read the provided dataset with `pd.read_excel`.
**Note: Remember to change the directory to the location where the excel sheet is located on your computer.**
df=pd.read_excel(r"C:\Users\BELLAVISTA\Documents\GitHub\QLAB_Summer_Python\_data\bogota_firms.xlsx",sheet_name='Results')
df.drop(columns=df.columns[0]) # This removes the first column that was named 'Unnamed: 0' in the excel file. It is not interesting to see it
# Out:
#                             Company name Latin alphabet Country ISO code  \
# 0     CONSORCIO CONTINENTAL PARA EL DESARROLLO SOSTE...               CO
# 1                 AGRET CARGA NACIONAL Y ESPECIAL S A S               CO
# 2                              DINASTIA INVERSIONES S A               CO
# 3                          BACKBONE COMUNICACIONES LTDA               CO
# 4                                   MACAOL ESPINOSA SAS               CO
# ...                                                 ...              ...
# 9995                                     GRADISPAN LTDA               CO
# 9996    CONTACTO ESTRATEGICO OUTSOURCING CONTABLE S A S               CO
# 9997                         JOSHUA CAFE IRLANDES S A S               CO
# 9998                    PROYECTO AGUAS DEL BOSQUE S A S               CO
# 9999                      GRUPO INVERSIONES SYNERGY SAS               CO
#
#      City\nLatin Alphabet  NACE Rev. 2, core code (4 digits)  \
# 0                    CALI                            4299.00
# 1                  BOGOTA                            4941.00
# 2            BARRANQUILLA                            4771.00
# 3                  BOGOTA                            6190.00
# 4                  BOGOTA                            6820.00
# ...                   ...                                ...
# 9995               BOGOTA                            4631.00
# 9996               BOGOTA                            6920.00
# 9997               BOGOTA                            5610.00
# 9998             MEDELLIN                            4110.00
# 9999              POPAYAN                            4110.00
#
#      Consolidation code  Last avail. year  \
# 0                    U1              2022
# 1                    U1              2022
# 2                    U1              2007
# 3                    U1              2022
# 4                    U1              2022
# ...                 ...               ...
# 9995                 U1              2011
# 9996                 U1              2022
# 9997                 U1              2018
# 9998                 U1              2021
# 9999                 U1              2020
#
#      Operating revenue (Turnover)\nth LCU 2023  \
# 0                                         n.a.
# 1                                         n.a.
# 2                                         n.a.
# 3                                         n.a.
# 4                                         n.a.
# ...                                        ...
# 9995                                      n.a.
# 9996                                      n.a.
# 9997                                      n.a.
# 9998                                      n.a.
# 9999                                      n.a.
#
#      Operating revenue (Turnover)\nth USD 2023  \
# 0                                         n.a.
# 1                                         n.a.
# 2                                         n.a.
# 3                                         n.a.
# 4                                         n.a.
# ...                                        ...
# 9995                                      n.a.
# 9996                                      n.a.
# 9997                                      n.a.
# 9998                                      n.a.
# 9999                                      n.a.
#
#      Operating revenue (Turnover)\nth LCU 2022  \
# 0                                      4769810
# 1                                   4769796.50
# 2                                         n.a.
# 3                                   4769348.62
# 4                                      4769148
# ...                                        ...
# 9995                                      n.a.
# 9996                                3736339.15
# 9997                                      n.a.
# 9998                                      n.a.
# 9999                                      n.a.
#
#      Operating revenue (Turnover)\nth USD 2022  ...  \
# 0                                       991.60  ...
# 1                                       991.60  ...
# 2                                         n.a.  ...
# 3                                       991.51  ...
# 4                                       991.47  ...
# ...                                        ...  ...
# 9995                                      n.a.  ...
# 9996                                    776.75  ...
# 9997                                      n.a.  ...
# 9998                                      n.a.  ...
# 9999                                      n.a.  ...
#
#      Operating revenue (Turnover)\nth LCU 2015  \
# 0                                     58155914
# 1                                         n.a.
# 2                                         n.a.
# 3                                      1170331
# 4                                       165799
# ...                                        ...
# 9995                                      n.a.
# 9996                                1012683.30
# 9997                                      n.a.
# 9998                                      n.a.
# 9999                                 136867.80
#
#      Operating revenue (Turnover)\nth USD 2015  \
# 0                                     18465.30
# 1                                         n.a.
# 2                                         n.a.
# 3                                       371.60
# 4                                        52.64
# ...                                        ...
# 9995                                      n.a.
# 9996                                    321.54
# 9997                                      n.a.
# 9998                                      n.a.
# 9999                                     43.46
#
#      Operating revenue (Turnover)\nth LCU 2014  \
# 0                                     51813164
# 1                                         n.a.
# 2                                         n.a.
# 3                                    874868.65
# 4                                       303235
# ...                                        ...
# 9995                                      n.a.
# 9996                                1032912.11
# 9997                                1827067.15
# 9998                                      n.a.
# 9999                                      n.a.
#
#      Operating revenue (Turnover)\nth USD 2014  \
# 0                                     21656.86
# 1                                         n.a.
# 2                                         n.a.
# 3                                       365.68
# 4                                       126.75
# ...                                        ...
# 9995                                      n.a.
# 9996                                    431.74
# 9997                                    763.68
# 9998                                      n.a.
# 9999                                      n.a.
#
#      Operating revenue (Turnover)\nth LCU 2013  \
# 0                                     23800831
# 1                                         n.a.
# 2                                         n.a.
# 3                                       532706
# 4                                       245349
# ...                                        ...
# 9995                                      n.a.
# 9996                                 920263.43
# 9997                                   1353686
# 9998                                      n.a.
# 9999                                      n.a.
#
#      Operating revenue (Turnover)\nth USD 2013  \
# 0                                     12379.76
# 1                                         n.a.
# 2                                         n.a.
# 3                                       277.08
# 4                                       127.62
# ...                                        ...
# 9995                                      n.a.
# 9996                                    478.67
# 9997                                    704.11
# 9998                                      n.a.
# 9999                                      n.a.
#
#      Operating revenue (Turnover)\nth LCU 2012  \
# 0                                         n.a.
# 1                                         n.a.
# 2                                         n.a.
# 3                                         n.a.
# 4                                         n.a.
# ...                                        ...
# 9995                                      n.a.
# 9996                                      n.a.
# 9997                                    880349
# 9998                                      n.a.
# 9999                                      n.a.
#
#      Operating revenue (Turnover)\nth USD 2012  \
# 0                                         n.a.
# 1                                         n.a.
# 2                                         n.a.
# 3                                         n.a.
# 4                                         n.a.
# ...                                        ...
# 9995                                      n.a.
# 9996                                      n.a.
# 9997                                    496.94
# 9998                                      n.a.
# 9999                                      n.a.
#
#      Operating revenue (Turnover)\nth LCU 2011  \
# 0                                         n.a.
# 1                                         n.a.
# 2                                         n.a.
# 3                                         n.a.
# 4                                         n.a.
# ...                                        ...
# 9995                                   1509000
# 9996                                      n.a.
# 9997                                    293967
# 9998                                      n.a.
# 9999                                      n.a.
#
#      Operating revenue (Turnover)\nth USD 2011
# 0                                         n.a.
# 1                                         n.a.
# 2                                         n.a.
# 3                                         n.a.
# 4                                         n.a.
# ...                                        ...
# 9995                                    776.75
# 9996                                      n.a.
# 9997                                    151.32
# 9998                                      n.a.
# 9999                                      n.a.
#
# [10000 rows x 32 columns]

# %%
##Before viewing the descriptive statistics of the dataset it is convenient to replace the `n.a.` strings by numpy type objects that represent a `np.nan`.
df.replace('n.a.', np.nan, inplace=True)
df
# Out:
#       Unnamed: 0                        Company name Latin alphabet  \
# 0           1.00  CONSORCIO CONTINENTAL PARA EL DESARROLLO SOSTE...
# 1           2.00              AGRET CARGA NACIONAL Y ESPECIAL S A S
# 2           3.00                           DINASTIA INVERSIONES S A
# 3           4.00                       BACKBONE COMUNICACIONES LTDA
# 4           5.00                                MACAOL ESPINOSA SAS
# ...          ...                                                ...
# 9995     9996.00                                     GRADISPAN LTDA
# 9996     9997.00    CONTACTO ESTRATEGICO OUTSOURCING CONTABLE S A S
# 9997     9998.00                         JOSHUA CAFE IRLANDES S A S
# 9998     9999.00                    PROYECTO AGUAS DEL BOSQUE S A S
# 9999    10000.00                      GRUPO INVERSIONES SYNERGY SAS
#
#      Country ISO code City\nLatin Alphabet  NACE Rev. 2, core code (4 digits)  \
# 0                  CO                 CALI                            4299.00
# 1                  CO               BOGOTA                            4941.00
# 2                  CO         BARRANQUILLA                            4771.00
# 3                  CO               BOGOTA                            6190.00
# 4                  CO               BOGOTA                            6820.00
# ...               ...                  ...                                ...
# 9995               CO               BOGOTA                            4631.00
# 9996               CO               BOGOTA                            6920.00
# 9997               CO               BOGOTA                            5610.00
# 9998               CO             MEDELLIN                            4110.00
# 9999               CO              POPAYAN                            4110.00
#
#      Consolidation code  Last avail. year  \
# 0                    U1              2022
# 1                    U1              2022
# 2                    U1              2007
# 3                    U1              2022
# 4                    U1              2022
# ...                 ...               ...
# 9995                 U1              2011
# 9996                 U1              2022
# 9997                 U1              2018
# 9998                 U1              2021
# 9999                 U1              2020
#
#       Operating revenue (Turnover)\nth LCU 2023  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 9995                                        NaN
# 9996                                        NaN
# 9997                                        NaN
# 9998                                        NaN
# 9999                                        NaN
#
#       Operating revenue (Turnover)\nth USD 2023  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 9995                                        NaN
# 9996                                        NaN
# 9997                                        NaN
# 9998                                        NaN
# 9999                                        NaN
#
#       Operating revenue (Turnover)\nth LCU 2022  ...  \
# 0                                    4769810.00  ...
# 1                                    4769796.50  ...
# 2                                           NaN  ...
# 3                                    4769348.62  ...
# 4                                    4769148.00  ...
# ...                                         ...  ...
# 9995                                        NaN  ...
# 9996                                 3736339.15  ...
# 9997                                        NaN  ...
# 9998                                        NaN  ...
# 9999                                        NaN  ...
#
#       Operating revenue (Turnover)\nth LCU 2015  \
# 0                                   58155914.00
# 1                                           NaN
# 2                                           NaN
# 3                                    1170331.00
# 4                                     165799.00
# ...                                         ...
# 9995                                        NaN
# 9996                                 1012683.30
# 9997                                        NaN
# 9998                                        NaN
# 9999                                  136867.80
#
#       Operating revenue (Turnover)\nth USD 2015  \
# 0                                      18465.30
# 1                                           NaN
# 2                                           NaN
# 3                                        371.60
# 4                                         52.64
# ...                                         ...
# 9995                                        NaN
# 9996                                     321.54
# 9997                                        NaN
# 9998                                        NaN
# 9999                                      43.46
#
#       Operating revenue (Turnover)\nth LCU 2014  \
# 0                                   51813164.00
# 1                                           NaN
# 2                                           NaN
# 3                                     874868.65
# 4                                     303235.00
# ...                                         ...
# 9995                                        NaN
# 9996                                 1032912.11
# 9997                                 1827067.15
# 9998                                        NaN
# 9999                                        NaN
#
#       Operating revenue (Turnover)\nth USD 2014  \
# 0                                      21656.86
# 1                                           NaN
# 2                                           NaN
# 3                                        365.68
# 4                                        126.75
# ...                                         ...
# 9995                                        NaN
# 9996                                     431.74
# 9997                                     763.68
# 9998                                        NaN
# 9999                                        NaN
#
#       Operating revenue (Turnover)\nth LCU 2013  \
# 0                                   23800831.00
# 1                                           NaN
# 2                                           NaN
# 3                                     532706.00
# 4                                     245349.00
# ...                                         ...
# 9995                                        NaN
# 9996                                  920263.43
# 9997                                 1353686.00
# 9998                                        NaN
# 9999                                        NaN
#
#       Operating revenue (Turnover)\nth USD 2013  \
# 0                                      12379.76
# 1                                           NaN
# 2                                           NaN
# 3                                        277.08
# 4                                        127.62
# ...                                         ...
# 9995                                        NaN
# 9996                                     478.67
# 9997                                     704.11
# 9998                                        NaN
# 9999                                        NaN
#
#       Operating revenue (Turnover)\nth LCU 2012  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 9995                                        NaN
# 9996                                        NaN
# 9997                                  880349.00
# 9998                                        NaN
# 9999                                        NaN
#
#       Operating revenue (Turnover)\nth USD 2012  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 9995                                        NaN
# 9996                                        NaN
# 9997                                     496.94
# 9998                                        NaN
# 9999                                        NaN
#
#       Operating revenue (Turnover)\nth LCU 2011  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 9995                                 1509000.00
# 9996                                        NaN
# 9997                                  293967.00
# 9998                                        NaN
# 9999                                        NaN
#
#       Operating revenue (Turnover)\nth USD 2011
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 9995                                     776.75
# 9996                                        NaN
# 9997                                     151.32
# 9998                                        NaN
# 9999                                        NaN
#
# [10000 rows x 33 columns]

# %%
##With the `describe` method we obtain some descriptive statistics of the provided dataset. For example, we obtain the total number of observations, the mean, the standard error, the minimum and the maximum.
df.drop(columns=df.columns[0]).describe()
# Out:
#        NACE Rev. 2, core code (4 digits)  Last avail. year  \
# count                            9650.00          10000.00
# mean                             4842.84           2020.30
# std                              2167.76              3.67
# min                               100.00           2005.00
# 25%                              4299.00           2021.00
# 50%                              4690.00           2022.00
# 75%                              6120.00           2022.00
# max                              9609.00           2023.00
#
#        Operating revenue (Turnover)\nth LCU 2023  \
# count                                      55.00
# mean                                  3583175.12
# std                                    272228.74
# min                                   3095243.01
# 25%                                   3382512.31
# 50%                                   3491920.01
# 75%                                   3797109.26
# max                                   4102740.33
#
#        Operating revenue (Turnover)\nth USD 2023  \
# count                                      55.00
# mean                                      874.73
# std                                        58.96
# min                                       776.77
# 25%                                       824.05
# 50%                                       872.84
# 75%                                       923.41
# max                                       979.93
#
#        Operating revenue (Turnover)\nth LCU 2022  \
# count                                    7454.00
# mean                                  4220827.26
# std                                    445583.67
# min                                   1805655.53
# 25%                                   3945187.20
# 50%                                   4187058.19
# 75%                                   4471133.63
# max                                  25722872.15
#
#        Operating revenue (Turnover)\nth USD 2022  \
# count                                    7454.00
# mean                                      877.84
# std                                        92.46
# min                                       375.38
# 25%                                       820.48
# 50%                                       870.60
# 75%                                       929.94
# max                                      5347.57
#
#        Operating revenue (Turnover)\nth LCU 2021  \
# count                                    6271.00
# mean                                  3937949.01
# std                                  20368882.77
# min                                         0.01
# 25%                                   2460785.78
# 50%                                   3272327.00
# 75%                                   3901790.50
# max                                1397339800.00
#
#        Operating revenue (Turnover)\nth USD 2021  \
# count                                    6271.00
# mean                                      989.94
# std                                      5116.24
# min                                         0.00
# 25%                                       619.15
# 50%                                       822.64
# 75%                                       980.06
# max                                    350988.12
#
#        Operating revenue (Turnover)\nth LCU 2020  \
# count                                    5246.00
# mean                                  2954496.61
# std                                   7380230.28
# min                                       100.00
# 25%                                   1497158.29
# 50%                                   2463450.86
# 75%                                   3343052.20
# max                                 279274000.00
#
#        Operating revenue (Turnover)\nth USD 2020  ...  \
# count                                    5246.00  ...
# mean                                      857.55  ...
# std                                      2142.37  ...
# min                                         0.03  ...
# 25%                                       434.60  ...
# 50%                                       715.10  ...
# 75%                                       970.44  ...
# max                                     81068.83  ...
#
#        Operating revenue (Turnover)\nth LCU 2015  \
# count                                    4357.00
# mean                                  3155237.67
# std                                  17512166.22
# min                                         1.00
# 25%                                   1111425.00
# 50%                                   2119000.00
# 75%                                   3190847.56
# max                                1090990994.00
#
#        Operating revenue (Turnover)\nth USD 2015  \
# count                                    4357.00
# mean                                     1001.92
# std                                      5560.35
# min                                         0.00
# 25%                                       353.31
# 50%                                       672.81
# 75%                                      1013.14
# max                                    346404.63
#
#        Operating revenue (Turnover)\nth LCU 2014  \
# count                                    3994.00
# mean                                  3416878.91
# std                                  42882675.84
# min                                         5.00
# 25%                                    949732.76
# 50%                                   1944780.92
# 75%                                   2993913.30
# max                                2675146830.00
#
#        Operating revenue (Turnover)\nth USD 2014  \
# count                                    3994.00
# mean                                     1428.36
# std                                     17924.09
# min                                         0.00
# 25%                                       396.97
# 50%                                       813.36
# 75%                                      1251.40
# max                                   1118157.37
#
#        Operating revenue (Turnover)\nth LCU 2013  \
# count                                    3922.00
# mean                                  3623917.75
# std                                  40679698.39
# min                                         0.00
# 25%                                    851848.66
# 50%                                   1706075.06
# 75%                                   2801967.58
# max                                2017636054.00
#
#        Operating revenue (Turnover)\nth USD 2013  \
# count                                    3922.00
# mean                                     1884.96
# std                                     21159.13
# min                                         0.00
# 25%                                       443.08
# 50%                                       887.40
# 75%                                      1457.41
# max                                   1049452.85
#
#        Operating revenue (Turnover)\nth LCU 2012  \
# count                                    1468.00
# mean                                  2810937.98
# std                                  18713756.26
# min                                         0.00
# 25%                                    832639.00
# 50%                                   1574790.37
# 75%                                   2479645.55
# max                                 697567000.00
#
#        Operating revenue (Turnover)\nth USD 2012  \
# count                                    1468.00
# mean                                     1586.42
# std                                     10563.56
# min                                         0.00
# 25%                                       470.01
# 50%                                       888.94
# 75%                                      1399.71
# max                                    393763.04
#
#        Operating revenue (Turnover)\nth LCU 2011  \
# count                                    1064.00
# mean                                  2684463.99
# std                                   6710600.98
# min                                         0.00
# 25%                                    901411.75
# 50%                                   1629500.00
# 75%                                   2353684.58
# max                                 114176000.00
#
#        Operating revenue (Turnover)\nth USD 2011
# count                                    1064.00
# mean                                     1382.04
# std                                      3454.25
# min                                         0.00
# 25%                                       464.00
# 50%                                       838.78
# 75%                                      1216.02
# max                                     58771.81
#
# [8 rows x 28 columns]

# %% [markdown]
# 2. Reshape the dataset from wide to long at year level. Drop columns if they are in Dollars. Keep columns from Operating revenue (Turnover) th LCU 2023 to the end, and the name of the firm.

# %% [markdown]
# 3. Rename the columns and use short names for each column. This new name should be shorter than 20 characters.

# %% [markdown]
# 4. Generate a dictionary with the definition of all the columns in your dataset.

# %% [markdown]
# 5. Generate a function named as calling_data that take as input the `name of the firm  or list of names (firm_name)` and `(start_year, end_year)`. The function should return a tuple with a dataframe with the same format as the one resulting from task 1-4, and your dictionary of columns. The function should work without `end_year`. It means it only takes `start_year`.

# %% [markdown]
# 6. Generate a class that do the same as the function, but has a method named as `descripitive` that gives you the mean, max, min, median, and rolling average .
