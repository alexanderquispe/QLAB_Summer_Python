# %% [markdown]
# ## Assignment 3 del Grupo 2
#
# #### Miembros:
# * Angie Quispe
# * Carlos Crespin
# * Jenny Tello

# %% [markdown]
# ## 1. Numpy

# %% [markdown]
# ## 2. Pandas

# %%
#Instalamos savReaderWriter
# !pip install savReaderWriter
# Out:
# ...
#   Created wheel for savReaderWriter: filename=savReaderWriter-3.4.2-py3-none-any.whl size=51142028 sha256=3e735ed3145c5b3980394be5623e17de3519740db4483072ed22f5ce2b54bd16
#   Stored in directory: c:\users\msi\appdata\local\pip\cache\wheels\cb\a1\bf\2b0abba03732dda64bac1510f20b5d34cae4fe071dc0699336
# Successfully built savReaderWriter
# ...

# %%
#Instalamos pyreadstat
# !pip install pyreadstat

# %%
#Importamos
import savReaderWriter as sav
import pandas as pd

# %%
#Importamos la base de datos
rec1 = pd.read_spss("C:/Users/MSI/Desktop/QLAB/Python para CCSS/Data/REC0111.sav" )

# Get labels from sav file
with sav.SavHeaderReader("C:/Users/MSI/Desktop/QLAB/Python para CCSS/Data/REC0111.sav", ioUtf8=True) as header:
    metadata = header.all()

dict_varlabels = metadata[3]

# %%
#Comprobamos la data
metadata

# %%
#Exploramos los labels de la data
dict_varlabels

# %%
#Revisamos la data
rec1
# Out:
#           ID1             HHID              CASEID    V001  V002  V003  \
# 0      2019.0        000100201        000100201  2     1.0   2.0   2.0
# 1      2019.0        000100201        000100201  3     1.0   2.0   3.0
# 2      2019.0        000102801        000102801  2     1.0  28.0   2.0
# 3      2019.0        000102801        000102801  6     1.0  28.0   6.0
# 4      2019.0        000104801        000104801  2     1.0  48.0   2.0
# ...       ...              ...                 ...     ...   ...   ...
# 38330  2019.0        325406201        325406201  2  3254.0  62.0   2.0
# 38331  2019.0        325406301        325406301  2  3254.0  63.0   2.0
# 38332  2019.0        325407001        325407001  2  3254.0  70.0   2.0
# 38333  2019.0        325407201        325407201  2  3254.0  72.0   2.0
# 38334  2019.0        325407401        325407401  2  3254.0  74.0   2.0
#
#          V004    V007    V008  V009  ...  QD333_4  QD333_5  QD333_6  UBIGEO  \
# ...

# %%
#Lo convertimos a dataframe

data= pd.DataFrame(rec1)

# %% [markdown]
# ### 2.1 Check if CASEID identifies each observation uniquely. Hint: Use is_unique method.

# %%
# Aplicamos is_unique property para CASEID

data_CASEID = data.loc[ : , "CASEID"]
data_CASEID
# Out:
# 0              000100201  2
# 1              000100201  3
# 2              000102801  2
# 3              000102801  6
# 4              000104801  2
#                 ...
# 38330          325406201  2
# 38331          325406301  2
# 38332          325407001  2
# 38333          325407201  2
# 38334          325407401  2
# Name: CASEID, Length: 38335, dtype: object

# %%
type(data_CASEID)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ##### Respuesta 1: CASEID is Unique

# %%
#RPTA
print(" CASEID is Unique: ", data_CASEID.is_unique)
# Out:
#  CASEID is Unique:  True

# %% [markdown]
# ### 2.2 Make the CASEID column the index of your data set.

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
#Utilizamos set_index para cambiar el index con la columna existente CASEID
data.set_index("CASEID")
# Out:
#                        ID1             HHID    V001  V002  V003    V004  \
# CASEID
#       000100201  2  2019.0        000100201     1.0   2.0   2.0     1.0
#       000100201  3  2019.0        000100201     1.0   2.0   3.0     1.0
#       000102801  2  2019.0        000102801     1.0  28.0   2.0     1.0
#       000102801  6  2019.0        000102801     1.0  28.0   6.0     1.0
#       000104801  2  2019.0        000104801     1.0  48.0   2.0     1.0
# ...                    ...              ...     ...   ...   ...     ...
#       325406201  2  2019.0        325406201  3254.0  62.0   2.0  3254.0
#       325406301  2  2019.0        325406301  3254.0  63.0   2.0  3254.0
#       325407001  2  2019.0        325407001  3254.0  70.0   2.0  3254.0
#       325407201  2  2019.0        325407201  3254.0  72.0   2.0  3254.0
#       325407401  2  2019.0        325407401  3254.0  74.0   2.0  3254.0
#
#                       V007    V008  V009    V010  ...  QD333_4  QD333_5  \
# ...

# %% [markdown]
# ### 2.3 Keep women who are 15-30 years old and live in Urban areas.

# %%
labels_data = metadata.valueLabels
labels_data
# Out:
# {'V013': {0.0: 'De 12 a 14 años de edad',
#   1.0: 'De 15 a 19 años de edad',
#   2.0: 'De 20 a 24 años de edad',
#   3.0: 'De 25 a 29 años de edad',
#   4.0: 'De 30 a 34 años de edad',
#   5.0: 'De 35 a 39 años de edad',
#   6.0: 'De 40 a 44 años de edad',
#   7.0: 'De 45 a 49 años de edad'},
#  'V014': {1.0: 'Mes y año',
#   2.0: 'Mes y edad - año imputado',
#   3.0: 'Año y edad - mes imputado',
#   4.0: 'Año y edad - año ignorado supera el año de entrevista',
#   5.0: 'Año - edad y mes imputados',
#   6.0: 'Edad - año y mes imputados',
#   7.0: 'Mes - edad y año imputados',
#   8.0: 'Ninguno - edad, mes y año imputados'},
#  'V015': {1.0: 'Completa',
#   2.0: 'Ausente',
#   3.0: 'Aplazada',
#   4.0: 'Rechazada',
#   5.0: 'Incoompleta',
#   6.0: 'Discapacitada',
#   7.0: 'Otra'},
#  'V018': {0.0: 'Sin calendario'},
#  'V019': {0.0: 'Sin calendario'},
#  'V020': {0.0: 'Toda la mujer muestra', 1.0: 'Alguna muestra casada'},
#  'V023': {1.0: 'Amazonas',
#   2.0: 'Ancash',
# ...

# %% [markdown]
# NOTA:
# 'V013': {0.0: 'De 12 a 14 años de edad',
#   1.0: 'De 15 a 19 años de edad',
#   2.0: 'De 20 a 24 años de edad',
#   3.0: 'De 25 a 29 años de edad'
#
# 'V140': {1.0: 'Área urbana',
#   2.0: 'Área rural',
#   7.0: 'No es residente habitual'},
#
#   'V025': {1.0: 'Urbano', 2.0: 'Rural'},

# %%
data_urban = data.loc[(data.V025 == 1.0)]
data_urban
# Out:
# Empty DataFrame
# Columns: [ID1, HHID, CASEID, V001, V002, V003, V004, V007, V008, V009, V010, V011, V012, V013, V014, V015, V017, V018, V019, V019A, V020, V021, V023, V024, V025, V026, V027, V028, V029, V030, V031, V032, V033, V034, V040, V042, V043, V044, V000, Q105DD, V101, V102, V103, V104, V105, V106, V107, V113, V115, V116, V119, V120, V121, V122, V123, V124, V125, V127, V128, V129, V130, V131, V133, V134, V135, V136, V137, V138, V139, V140, V141, V149, V150, V151, V152, V153, AWFACTT, AWFACTU, AWFACTR, AWFACTE, AWFACTW, V155, V156, V157, V158, V159, V160, V161, V166, V167, V168, ML101, QD333_1, QD333_2, QD333_3, QD333_4, QD333_5, QD333_6, UBIGEO, V022, ...]
# Index: []
#
# [0 rows x 105 columns]

# %%
data_urban = data.query( 'V013 == 1.0')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [70], in <cell line: 1>()
# ----> 1 data_urban = df.query( 'V013 == 1.0')
#
# NameError: name 'df' is not defined
